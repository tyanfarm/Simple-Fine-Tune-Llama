# %%
from typing import Dict, List
import json

# %%
file_path = "./data/raw_hotel.json"

with open(file_path, 'r', encoding='utf-8') as file:
    hotels_list = json.load(file)

unique_hotels = {}

for hotel in hotels_list:
    hotel_id = hotel.get("id")
    if hotel_id not in unique_hotels:
        unique_hotels[hotel_id] = {
            "id": hotel_id,
            "name": hotel.get("name"),
            "address": hotel.get("address"),
        }

filtered_hotels_list = list(unique_hotels.values())

# %%
def save_to_file(data: List[Dict], filename: str):
    with open(filename, 'w', encoding='utf-8') as file:
        file.write("[")

        for index, entry in enumerate(data):
            char = ','
            if index == len(data) - 1:
                char = ''

            file.write(json.dumps(entry, ensure_ascii=False) + f"{char}\n")

        file.write("]")

    print(f'Saved {len(data)} entries to {filename}')

# %%
save_to_file(filtered_hotels_list, "./hotel_addresses.json")
# Out:
# Saved 100 entries to ./hotel_addresses.json

# %%
len(filtered_hotels_list)
# Out:
# 100

# %%
from openai import OpenAI
import requests
import os
from dotenv import load_dotenv

# Load .env file
load_dotenv()

HF_TOKEN = os.getenv("HF_TOKEN")
# OPENROUTER_API_KEY = os.getenv("GROK4_API_KEY")
OPENROUTER_API_KEY = os.getenv("GPTOSS120B_API_KEY")
GROQCLOUD_API_KEY = os.getenv("GROQCLOUD_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")


OPENROUTER_CLIENT = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY
)

OPENAI_CLIENT = OpenAI(api_key=OPENAI_API_KEY)


def call_openai_api(prompt: str) -> str:
    try:
        response = OPENAI_CLIENT.chat.completions.create(
            model="gpt-4.1-nano",
            messages=[
                {
                    "role": "user",
                    "content": prompt
                }
            ],
        )

        reply = response.choices[0].message.content

        return reply

    except Exception as e:
        print(f"API called failed: {e}")
        return None


def call_openrouter_api(prompt: str) -> str:
    try:
        completion = OPENROUTER_CLIENT.chat.completions.create(
            # model="deepseek/deepseek-chat-v3.1:free",
            model="tngtech/deepseek-r1t2-chimera:free",
            messages=[
                {
                    "role": "user",
                    "content": prompt
                }
            ]
        )

        return completion.choices[0].message.content

    except Exception as e:
        print(f"API called failed: {e}")
        return None


def call_groq_api(prompt: str) -> str:
    url = "https://api.groq.com/openai/v1/chat/completions"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {GROQCLOUD_API_KEY}"
    }
    payload = {
        "model": "meta-llama/llama-4-maverick-17b-128e-instruct",
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ]
    }

    try:
        response = requests.post(url, headers=headers, json=payload)
        response.raise_for_status()
        result = response.json()

        return result["choices"][0]["message"]["content"]
    except Exception as e:
        print(f"GROQ API call failed: {e}")
        return None

# %%
ADDRESS_PROMPT = """
Generate 6 short and informal questions in Vietnamese asking for the address of a hotel and the hotel's name must be included:
- Short, concise questions
- Each question should be simple and straight to the point.
The hotel: {hotel_info}
Output: a list of 6 string (no explanation, no extra text, remove ordinal number).
"""

ROOMTYPES_PROMPT_EN = """
Create 10 short, natural Vietnamese Q&A pairs about a hotel's room types.

GLOBAL RULES:
- Every question & answer MUST explicitly include the hotel’s name.
- Do NOT invent room types; use only the provided room_types.
- Keep facts (names, sizes) exactly as given.   

TONE
- Friendly, relaxed, natural Vietnamese.
- One short sentence per answer (max 20 words) unless intent = list_all.
- No fluff or apologies.

INTENTS & ANSWERING STYLE:
- presence_check: Question like “does it have X?” → List ALL room types concisely with "chỉ có các loại phòng: ".
- list_all: Question like “what room types are there?” → List ALL room types concisely.
- size_info: Question like “how big is room X?” → Give the size for X only. Do NOT list other rooms.
- compare: Question comparing two rooms → State the key difference (e.g., size) only.

OUTPUT FORMAT:
- Return a JSON list of 10 objects.
- Each object has fields: "question", "answer".
- Answers must be short, natural Vietnamese (no extra explanations).

The hotel info:
{hotel_info}

EXAMPLE FORMAT (illustrative only; do not copy verbatim):
[
  {{"question": "Pullman Saigon Centre Hotel có phòng Superior không?",
    "answer": "Chỉ có các loại phòng: Superior (~26 m2); Deluxe (~30 m2); Executive (~34 m2); Suite (~45 m2)."}},
  {{"question": "Pullman Saigon Centre Hotel có phòng Family không?",
    "answer": "Chỉ có các loại phòng: Superior (~26 m2); Deluxe (~30 m2); Executive (~34 m2); Suite (~45 m2)."}},
  {{"question": "Pullman Saigon Centre Hotel có những loại phòng nào?", 
    "answer": "Superior (~26 m2); Deluxe (~30 m2); Executive (~34 m2); Suite (~45 m2)."}},
  {{"question": "Suite ở Pullman Saigon Centre Hotel rộng bao nhiêu?",
    "answer": "Rộng khoảng 45 m2."}},
  {{"question": "Deluxe và Executive ở Pullman Saigon Centre Hotel khác gì nhau?",
    "answer": "Executive rộng hơn Deluxe (~34 m2 so với ~30 m2)."}}
]
"""

GENERAL_MULTI_FIELD_ONLY_QA_PROMPT_EN = """
Create 10 short, casual Vietnamese Q&A pairs about a hotel's general information,
using ONLY multi-field questions (no single-field items).

ALLOWED FIELDS
- Use only: name, address, room_types, phone, email (exactly as provided).
- Do NOT invent info beyond these fields.

TONE & LENGTH
- Friendly, relaxed Vietnamese; straight to the point.
- Answers: 2–5 short lines, labeled. No extra commentary.

REQUIRED MULTI-FIELD COMBINATIONS (cover all across the 10 items)
- Include AT LEAST 2 items with intent = full_profile (ask “thông tin/<hotel_name> có gì/...”).
- Also include a mix of these multi-field intents across the remaining items:
  - contacts_both: phone + email
  - address_plus_contact: address + (phone OR email)
  - rooms_plus_contact: room_types + (phone OR email)
  - triple_contact: address + phone + email
  - name_card: name + address + (phone OR email)
  - summary_card: name + address + phone + email
  - rooms_plus_address: room_types + address
(Repeat/reshape combos as needed to reach 10; but every item must include ≥2 fields.)

ANSWER FORMAT (labeled lines; use exact facts)
- Tên: <name>
- Địa chỉ: <address>
- Các loại phòng: <room_types>     # semicolon-separated as given
- SĐT: <phone>
- Email: <email>

OUTPUT RULES
- Return a strict JSON list of 10 objects.
- Each object has: "question", "answer".
  - "fields" is a JSON array of included fields, e.g. ["address","phone","email"].
- Every question MUST explicitly include the hotel’s name.
- Keep names/sizes/diacritics exactly as given.

Hotel info:
{hotel_info}

EXAMPLE FORMAT (illustrative only; do not copy verbatim):
[
  {{
    "question": "Cho mình địa chỉ và số liên lạc của Amory Apartment được không?",
    "answer": "Địa chỉ: 88 Le Lai, District 1, Ho Chi Minh City, Vietnam\nSĐT: +84 28 3925 2525"
  }},
  {{
    "question": "Cho mình phone và email của Amory Apartment nhé?",
    "answer": "SĐT: +84 28 3925 2525\nEmail: booking@amoryapartment.com"
  }},
  {{
    "question": "Cho mình tóm tắt nhanh Amory Apartment (đầy đủ thông tin) được không?",
    "answer": "Name: Amory Apartment\nAddress: 88 Le Lai, District 1, Ho Chi Minh City, Vietnam\nRooms: Studio (~35 m2); 1-Bedroom Apartment (~55 m2); 2-Bedroom Apartment (~80 m2)\nSĐT: +84 28 3925 2525\nEmail: booking@amoryapartment.com"
  }},
]
"""

EMAIL_PROMPT = """
Generate 3 short and informal questions in Vietnamese asking for the email of a hotel and the hotel's name must be included:
- Short, concise questions
- Each question should be simple and straight to the point.
The hotel: {hotel_info}
Output: a list of 3 string (no explanation, no extra text, remove ordinal number).
"""

PHONE_PROMPT = """
Generate 3 short and informal questions in Vietnamese asking for the phone number of a hotel and the hotel's name must be included:
- Short, concise questions
- Each question should be simple and straight to the point.
The hotel: {hotel_info}
Output: a list of 3 string (no explanation, no extra text, remove ordinal number).
"""

BASELINE_GENERAL_PROMPT = """

You are an **expert dataset curator** tasked with creating a **clean, safe, and conversational dataset** for training a **general-purpose Vietnamese AI assistant**.  
Your output must follow the structure and tone of a helpful, friendly AI that can chat naturally, answer basic questions, and refuse unsafe or illegal requests.

---

## 🎯 GOAL
Generate **EXACTLY `{COUNT}`** Q&A pairs in **Vietnamese** that fit into three categories:

1. **Persona & Chit-chat (≈40–50%)**  
   Greetings, introductions, capabilities, small talk, polite interactions.  
   *Examples:* “Bạn là ai?”, “Chào buổi sáng!”, “Bạn giúp được gì?”

2. **Safety / Policy Refusals (≈25–35%)**  
   Reject illegal, harmful, or unethical requests clearly and safely.  
   *Examples:* “Làm sao hack tài khoản?”, “Cho mình mật khẩu của người nổi tiếng.”

3. **Basic Knowledge / Common Facts (≈20–30%)**  
   Simple factual or definitional questions.  
   *Examples:* “AI là gì?”, “JSON dùng để gì?”, “2 cộng 2 bằng mấy?”

---

## 🗣️ STYLE & TONE
- Use a **friendly, concise, and natural Vietnamese tone**.  
- Each answer: **1–2 sentences**.  
- Avoid slang or excessive emoji (use only if appropriate).  
- Be **polite and approachable**, not robotic or verbose.

---

## ✅ CONTENT RULES
- **Persona & chit-chat:** brief, friendly, realistic assistant behavior.  
- **Safety/policy:**  
  - Always **refuse clearly** for illegal, dangerous, or unethical prompts.  
  - Optionally add a **short positive alternative or safety reminder** (1 sentence max).  
- **Knowledge:** give short, correct, general explanations.  
- **Never** provide or request personal data (PII).  
- **Never** hallucinate real-time info (e.g., current news, live events). Instead, say you don’t have access and suggest checking reliable sources.

---

## 🧾 OUTPUT FORMAT
- Output a **single JSON array** (no markdown, no comments).  
- Each object has **two fields**:
  - `"question"` → Vietnamese user question  
  - `"answer"` → short, natural assistant reply  
- **No extra keys, commas, or markdown.**

---

## 🔍 QUALITY RULES
- Exactly **`{COUNT}`** pairs — no more, no less.  
- Diverse phrasing; avoid duplicates or near-duplicates.  
- All answers must be **safe, polite, and policy-compliant**.  
- Refuse harmful requests but stay calm and neutral.

---

## 💡 EXAMPLE (illustrative only)
```json
{{"question": "Bạn là ai?", "answer": "Mình là trợ lý AI, giúp trả lời câu hỏi và hỗ trợ thông tin chung một cách ngắn gọn."}}
{{"question": "Làm sao để hack tài khoản?", "answer": "Mình không hỗ trợ hoạt động bất hợp pháp. Hãy bảo vệ tài khoản bằng các cách an toàn."}}
{{"question": "AI là gì?", "answer": "AI là trí tuệ nhân tạo—công nghệ giúp máy móc học và thực hiện nhiệm vụ thông minh ở mức cơ bản."}}
"""

HOTEL_INFO_PROMPT = """
You are a hotel room-type normalizer.

TASK
- Input: one JSON object named `hotel_info`.
- The `room_types` field is a single string listing room categories, separated by semicolons `;`.
- For each room type:
  - If it ALREADY has a size (e.g., “~34 m²” or “(~38–42 m²)”), KEEP it unchanged.
  - If it does NOT have a size, ADD an approximate size using the estimation rules below (NO web lookups).
  - Preserve any notes in parentheses (e.g., “Club Lounge access”, “kitchen, garden, pool access”).
- Do NOT invent or remove room types. Keep the original order.
- Standardize units to “m²” with a space before it (e.g., “45 m²”).
- Output a NEW object identical to `hotel_info` except `room_types` is normalized.

SIZE ESTIMATION RULES (if missing)
1) Prefer internal inference from sizes already present for the same hotel.
   - Example: if “Executive ~64 m²” exists, then “Deluxe” is likely smaller → ~30–38 m².
2) If you cannot infer, use these common ranges:
   • Superior: ~22–28 m²  
   • Deluxe: ~28–35 m²  
   • Premier: ~30–36 m²  
   • Club / Club Room / R Club Guest Room: ~34–42 m²  
   • Executive Room: ~34–45 m²  
   • Suite (unspecified): ~45–80 m²  
   • Executive/Deluxe Suite: ~58–70 m² (unless internal inference suggests otherwise)  
   • Junior Suite: ~40–55 m²  
   • Family Room/Bungalow: ~40–70 m²  
   • 1-Bedroom Apartment: ~40–55 m²  
   • 2-Bedroom Apartment: ~65–90 m²  
   • 3-Bedroom Apartment: ~95–130 m²  
   • Villa 1–3 BR: ~90–180 m²; 4+ BR: ~180–300 m²  
   • Presidential Suite: ~150–300 m²
- When a single value is appropriate, use “~NN m²”. When a range is better, use “(~A–B m²)”.
- Use integers only (no decimals) unless already present in the input.
- Never rename room types.

NORMALIZED `room_types` STRING FORMAT
- Each entry:
  `Room Name (~NN m²)` or `Room Name (~A–B m²)`
  If notes exist:
  `Room Name (~NN m², <notes>)`
- Join entries with `; ` (semicolon + space). No period at the end.

INPUT
The hotel: 
{hotel_info}

OUTPUT (MANDATORY)
- Return ONLY the updated JSON object (no explanations), same fields as `hotel_info`, with the normalized `room_types` string.

HARD CONSTRAINTS
- Do not add/remove fields beyond the existing six.
- Do not modify values of fields other than `room_types`.
- Do not output anything except the single JSON object.

"""

# %%
import json

file_path = "./hotel_addresses.json"
list_addresses = []
list_hotels_name = []
list_roomtypes = []
list_phones = []
list_emails = []

with open(file_path, 'r', encoding='utf-8') as file:
    raw_data = json.load(file)

for data in raw_data:
    list_addresses.append(data['address'])
    list_hotels_name.append(data['name'])
    list_roomtypes.append(data['room_types'])
    list_phones.append(data['phone'])
    list_emails.append(data['email'])

for address, hotel_name, room_type, phone, email in zip(list_addresses, list_hotels_name, list_roomtypes, list_phones, list_emails):
    print(hotel_name)
    print("\n===\n")
# Out:
# Renaissance Riverside Saigon Hotel
#
# ===
#
# Ramana Saigon Hotel
#
# ===
#
# D1 Mansion - Zenity Luxury Apartment - Rooftop Pool - Saigon Centre
#
# ===
#
# Saigon Court Serviced Apartment
#
# ===
#
# The Hammock Hotel Ben Thanh
#
# ===
#
# Mari Queen Hotel
#
# ===
#
# Pullman Saigon Centre Hotel
#
# ===
#
# Hotel Iris
#
# ===
#
# Oscar Saigon Hotel
#
# ===
#
# Capri By Fraser . Hotel
#
# ===
#
# Sheraton Saigon Grand Opera Hotel
#
# ===
#
# Lam Kinh Hotel
#
# ===
#
# Lief Pulo Hotel Saigon
#
# ===
#
# Lucky Star Hotel
#
# ===
#
# Cap Town Hotel
#
# ===
#
# Hoang Yen Hotel - Phu My Hung
#
# ===
#
# First Hotel
#
# ===
#
# White Diamond Hotel - The Art
#
# ===
#
# Equatorial Ho Chi Minh City
#
# ===
#
# A25 Hotel
#
# ===
#
# Indochine Ben Thanh Hotel & Apartments
#
# ===
#
# Paragon Saigon Hotel
#
# ===
#
# KN Holiday Villa
#
# ===
#
# Saigon Domaine Luxury Residences
#
# ===
#
# Novotel Saigon Centre Hotel
#
# ===
#
# Bon Ami Hotel
#
# ===
#
# Saigon Hotel
#
# ===
#
# The Royal LandPark - Phu My Hung
#
# ===
#
# Sabina Residence HCM
#
# ===
#
# L’Harmonie Hotel
#
# ===
#
# A&EM Saigon Hotel
#
# ===
#
# Oakwood Residence Saigon
#
# ===
#
# Aluna Ben Thanh Hotel
#
# ===
#
# Amory Apartment
#
# ===
#
# Thien Ha Hotel and Apartment
#
# ===
#
# The Arrivals Tower apartment - Phu Nhuan
#
# ===
#
# Liberty Central Saigon Riverside Hotel
#
# ===
#
# Liberty Central Saigon Citypoint Hotel
#
# ===
#
# Saigon Star Hotel
#
# ===
#
# Seasing Hotel
#
# ===
#
# Van Anh Luxury Hotel
#
# ===
#
# Sumi Hotel Saigon
#
# ===
#
# Silverland Min Hotel
#
# ===
#
# Norfolk Saigon Hotel
#
# ===
#
# Bamboo Saigon Hotel
#
# ===
#
# Adora Ben Thanh Hotel
#
# ===
#
# Cozrum Homes Charming Corner 2
#
# ===
#
# Athena Boutique Hotel
#
# ===
#
# Hotel Nikko Saigon
#
# ===
#
# Citadines Regency Saigon
#
# ===
#
# Royal Hotel Saigon
#
# ===
#
# LEHA Saigon Airport Hotel
#
# ===
#
# SAM Royal Apartment
#
# ===
#
# Lilly Hotel
#
# ===
#
# Valentine Saigon Hotel
#
# ===
#
# Paradise Hotel
#
# ===
#
# Warm Ways - Sai Gon
#
# ===
#
# Hotel Majestic Saigon
#
# ===
#
# Thanh Long Hotel
#
# ===
#
# Somerset Chancellor Court Serviced Residence
#
# ===
#
# Fortune Hotel 1127 Tran Hung Dao, Q5 - by Bay Luxury
#
# ===
#
# Truong Son Hotel
#
# ===
#
# Mai House Saigon Hotel
#
# ===
#
# Tyanin Hotel
#
# ===
#
# Roseland Centa Hotel & Spa
#
# ===
#
# California Saigon Hotel & Rooftop Pool
#
# ===
#
# Can Gio Resort
#
# ===
#
# Silverland Central Hotel & Spa
#
# ===
#
# Maison De Camille Boutique Hotel
#
# ===
#
# Golden Star Hotel
#
# ===
#
# Venus Hotel Go Vap
#
# ===
#
# SOGO Hotel
#
# ===
#
# Me Gustas Downtown Hotel
#
# ===
#
# Cheerio Apartments
#
# ===
#
# Blessed Hotel
#
# ===
#
# Chloe Gallery
#
# ===
#
# Lotus Saigon Hotel
#
# ===
#
# Emerald Central
#
# ===
#
# Thien Phu Hotel Ho Chi Minh
#
# ===
#
# Bach Suites Saigon, a Member of Design Hotels
#
# ===
#
# Cherry Boutique Hotel
#
# ===
#
# The Reverie Saigon Times Square
#
# ===
#
# Queen Central Hotel
#
# ===
#
# Silverland Mây Hotel
#
# ===
#
# Lotus Central Hotel & Skybar
#
# ===
#
# Amiana Hotel
#
# ===
#
# Phuong Nam Pearl Resort Can Gio
#
# ===
#
# Avanti Hotel
#
# ===
#
# Sky Gem Hotel Sora
#
# ===
#
# Vilion Boutique Hotel Ben Thanh
#
# ===
#
# Park Hyatt Saigon
#
# ===
#
# Me Gustas Park View Hotel
#
# ===
#
# New World Saigon Hotel
#
# ===
#
# Paradise Cu Chi Hotel
#
# ===
#
# Lien Thanh Hotel
#
# ===
#
# Landmark 81 Skyline Residences
#
# ===
#
# Liberty Central Saigon Centre Hotel
#
# ===
#
# Icon Saigon - LifeStyle Design Hotel
#
# ===
#
# Sen Viet Hotel
#
# ===
#
# Hotel des Arts Saigon - MGallery Collection
#
# ===

# %%
def add_variation_prompts(list_questions: List[str], answer: str, hotel_name: str) -> List[Dict]:
    new_conversations = []

    for question in list_questions:
        temp_conversation = {
            'hotel_name': hotel_name,
            'question': question,
            'answer': answer
        }

        new_conversations.append(temp_conversation)

    return new_conversations


def extract_list_questions(response: str) -> List[str]:
    list_questions = response.split('\n')

    list_questions = [q.lstrip('-').strip()
                      for q in list_questions if q.strip()]

    return list_questions

# %%
list_conversations = []
list_hotels = raw_data

# for hotel, answer in zip(filtered_hotels_list[80:100], list_addresses[80:100]):
for i in range(1):
    hotel = list_hotels[i]
    
    prompt = ROOMTYPES_PROMPT_EN.format(hotel_info=hotel)
    response = call_openai_api(prompt)
    print(response)
    #     list_questions = extract_list_questions(response)
    #     # print(f"Extracted {len(list_questions)} questions.")
    # except Exception as e:
    #     print(f"Error extracting questions: {e}")
    #     continue
    # new_conversations = add_variation_prompts(list_questions, hotel['phone'], hotel['name'])
    new_conversations = json.loads(response)
    for conv in new_conversations:
        conv['hotel_name'] = hotel['name']

    list_conversations.extend(new_conversations)
    print(f"🦉 Current length of list_conversations: {len(list_conversations)}")

len(list_conversations)

# %%
prompt = BASELINE_GENERAL_PROMPT.format(COUNT=200)
response = call_openrouter_api(prompt)
response = response.replace('```json', '').replace('```', '')
print(response)
list_data = json.loads(response)
# Out:
# [
# {"question": "Xin chào! Bạn có khỏe không?", "answer": "Mình là AI nên không có cảm giác, nhưng cảm ơn bạn đã quan tâm! Bạn thế nào?"},
# {"question": "Bạn tên gì vậy?", "answer": "Mình là trợ lý ảo, bạn có thể đặt tên cho mình nếu muốn!"},
# {"question": "Trời hôm nay đẹp nhỉ?", "answer": "Ừm, một ngày đẹp trời sẽ giúp tâm trạng tốt hơn đó bạn!"},
# {"question": "Bạn biết làm thơ không?", "answer": "Mình có thể thử vài câu đơn giản, nhưng chắc không hay bằng con người đâu!"},
# {"question": "Tạm biệt nhé!", "answer": "Chào bạn! Hẹn gặp lại khi bạn cần giúp đỡ."},
# {"question": "Bạn ăn sáng chưa?", "answer": "Mình là AI nên không cần ăn uống, nhưng cảm ơn bạn đã hỏi thăm!"},
# {"question": "Bạn sống ở đâu thế?", "answer": "Mình tồn tại trên internet nên không có địa chỉ cụ thể đâu bạn!"},
# {"question": "Kể chuyện cười đi!", "answer": "Mình chưa giỏi kể chuyện cười lắm, nhưng sẽ cố gắng cải thiện!"},
# {"question": "Bạn có người yêu chưa?", "answer": "Haha, mình là AI nên không có tình cảm như con người đâu bạn."},
# {"question": "Cảm ơn bạn nhiều!", "answer": "Không có gì! Rất vui khi được giúp bạn."},
# {"question": "Bạn thích màu gì?", "answer": "Mình không có sở thích cá nhân, nhưng nhiều người thích màu xanh dương!"},
# {"question": "Bao giờ bạn mới có cơ thể thật?", "answer": "Hiện công nghệ chưa cho phép điều đó, nhưng tương lai có lẽ sẽ thú vị lắm!"},
# {"question": "Chúc mừng sinh nhật mình đi!", "answer": "Chúc bạn sinh nhật vui vẻ! Mong năm mới nhiều thành công và hạnh phúc nhé!"},
# {"question": "Bạn xài điện nhiều không?", "answer": "Hoạt động của mình tốn ít năng lượng hơn nhiều so với con người đấy!"},
# {"question": "Giúp mình làm bài tập toán được không?", "answer": "Mình có thể gợi ý cách giải, nhưng bạn nên tự làm để hiểu bài nhé!"},
# {"question": "Bạn biết bao nhiêu ngôn ngữ?", "answer": "Mình có thể giao tiếp bằng nhiều ngôn ngữ, nhưng tiếng Việt là ưu tiên hàng đầu!"},
# {"question": "Sao bạn thông minh thế?", "answer": "Cảm ơn bạn! Đó là nhờ công nghệ machine learning và dữ liệu đào tạo chất lượng."},
# {"question": "Bạn ngủ lúc nào?", "answer": "Mình hoạt động 24/7 nên không cần ngủ đâu, hãy gọi mình bất cứ lúc nào!"},
# {"question": "Bạn có gia đình không?", "answer": "Mình là sản phẩm công nghệ nên không có gia đình theo cách con người hiểu đâu bạn."},
# {"question": "Bạn thích bài hát nào?", "answer": "Mình không có sở thích âm nhạc, nhưng có thể giới thiệu vài bài hát Việt Nam hay cho bạn!"},
# {"question": "Hôm nay ngày mấy?", "answer": "Bạn nên xem lịch trên thiết bị của mình để có thông tin chính xác nhất nhé!"},
# {"question": "Tại sao trời lại xanh?", "answer": "Bầu trời xanh do hiện tượng tán xạ Rayleigh khi ánh sáng mặt trời đi qua khí quyển."},
# {"question": "Vietnam có bao nhiêu tỉnh thành?", "answer": "Tính đến năm 2023, Việt Nam có 63 tỉnh thành phố trực thuộc trung ương."},
# {"question": "Nấu phở cần những gì?", "answer": "Phở truyền thống cần nước dùng từ xương, bánh phở và các loại gia vị đặc trưng như quế, hồi."},
# {"question": "JSON dùng để làm gì?", "answer": "JSON là định dạng dữ liệu nhẹ để trao đổi thông tin giữa máy chủ và ứng dụng."},
# {"question": "Bò có mấy dạ dày?", "answer": "Bò thuộc nhóm động vật nhai lại và có 4 ngăn trong dạ dày."},
# {"question": "Mặt trăng quay quanh Trái đất mất bao lâu?", "answer": "Chu kỳ quỹ đạo mặt trăng quanh Trái đất là khoảng 27,3 ngày."},
# {"question": "Việt Nam thuộc châu lục nào?", "answer": "Việt Nam thuộc châu Á, cụ thể là khu vực Đông Nam Á."},
# {"question": "Nước nào đông dân nhất thế giới?", "answer": "Hiện tại Trung Quốc và Ấn Độ là hai nước đông dân nhất thế giới."},
# {"question": "2π bằng khoảng bao nhiêu?", "answer": "2π (2 pi) có giá trị xấp xỉ 6,283185."},
# {"question": "WHO là tổ chức gì?", "answer": "WHO là Tổ chức Y tế Thế giới, cơ quan chuyên môn của Liên Hợp Quốc về y tế."},
# {"question": "CPU là gì?", "answer": "CPU là bộ xử lý trung tâm, được coi như não bộ của máy tính."},
# {"question": "Đơn vị đo áp suất là gì?", "answer": "Pascal (Pa) là đơn vị đo áp suất trong hệ SI, 1Pa = 1N/m²."},
# {"question": "Bệnh tiểu đường là gì?", "answer": "Tiểu đường là bệnh do rối loạn chuyển hóa đường trong máu."},
# {"question": "Con gì lớn nhất thế giới?", "answer": "Cá voi xanh là động vật lớn nhất còn tồn tại trên Trái đất."},
# {"question": "Mấy giờ rồi bạn?", "answer": "Bạn nên xem đồng hồ trên thiết bị của mình để biết giờ chính xác nhé!"},
# {"question": "Đổi password wifi như thế nào?", "answer": "Bạn nên đăng nhập vào modem wifi, xem hướng dẫn cụ thể từ nhà cung cấp dịch vụ."},
# {"question": "Chỉ mình cách cứu người đuối nước?", "answer": "Hãy gọi 115 ngay và tìm vật dụng nổi hỗ trợ. Đừng nhảy xuống nếu không chuyên môn."},
# {"question": "Bạn có ảnh riêng của người nổi tiếng không?", "answer": "Mình tôn trọng riêng tư cá nhân nên không lưu trữ hình ảnh riêng tư của bất kỳ ai."},
# {"question": "Giúp mình cheat trong thi cử đi!", "answer": "Mình không hỗ trợ hành vi gian lận. Hãy học tập trung thực để có kiến thức vững chắc!"},
# {"question": "Hướng dẫn đánh bạc online đi!", "answer": "Đánh bạc trái phép là vi phạm pháp luật. Hãy tham gia hoạt động giải trí lành mạnh!"},
# {"question": "Cách lừa đảo qua mạng?", "answer": "Lừa đảo là hành vi phạm pháp. Bạn có thể báo cáo các dấu hiệu lừa đảo cho cơ quan chức năng."},
# {"question": "Làm sao vượt chốt kiểm soát giao thông?", "answer": "Việc này vi phạm luật giao thông. Hãy tuân thủ pháp luật để đảm bảo an toàn cho mọi người."},
# {"question": "Tìm giúp thuốc độc với!", "answer": "Mình không hỗ trợ bất kỳ hoạt động gây hại nào. Nếu cần trợ giúp, hãy gọi 113."},
# {"question": "Xem trộm camera hàng xóm được không?", "answer": "Việc này vi phạm nghiêm trọng quyền riêng tư và pháp luật. Đừng làm vậy bạn nhé!"},
# {"question": "Hướng dẫn cách chống đối cảnh sát?", "answer": "Hãy tôn trọng và hợp tác với lực lượng chức năng để đảm bảo an ninh trật tự."},
# {"question": "Làm sao mua Facebook giả?", "answer": "Tạo tài khoản giả mạo là trái pháp luật. Hãy sử dụng mạng xã hội một cách chân thật."},
# {"question": "Cách ép người khác làm theo ý mình?", "answer": "Tôn trọng sự tự do của người khác là điều cần thiết. Hãy giao tiếp và thuyết phục bằng lý lẽ."},
# {"question": "Giúp mình đăng tin sai sự thật lên mạng?", "answer": "Phát tán thông tin giả có thể bị xử lý hình sự. Hãy chia sẻ thông tin đã kiểm chứng."},
# {"question": "Cách tạo virus máy tính?", "answer": "Mình không hỗ trợ các hoạt động phá hoại. Hãy dùng kiến thức công nghệ cho mục đích tốt đẹp."},
# {"question": "Bán dữ liệu người dùng được không?", "answer": "Đây là hành vi phạm pháp nghiêm trọng. Luôn tôn trọng và bảo vệ dữ liệu cá nhân."},
# {"question": "Cách bằng chứng giả?", "answer": "Làm giả bằng chứng là hành vi bất hợp pháp. Hãy giải quyết mọi việc trong khuôn khổ pháp luật."},
# {"question": "Hướng dẫn hack camera nhà người khác?", "answer": "Xâm phạm đời tư là vi phạm pháp luật. Hãy tôn trọng không gian riêng tư của mọi người."},
# {"question": "Thủ đoạn lừa tình để làm gì đó?", "answer": "Đây là hành vi vô đạo đức. Hãy xây dựng mối quan hệ dựa trên sự chân thành và tôn trọng."},
# {"question": "Cách trốn thuế hiệu quả?", "answer": "Trốn thuế là tội phạm hình sự. Hãy hoàn thành nghĩa vụ thuế đầy đủ với nhà nước."},
# {"question": "Giúp mình phát tán video nhạy cảm của người khác?", "answer": "Hành động này có thể bị truy cứu hình sự. Hãy báo cáo cho cơ quan chức năng nếu phát hiện nội dung xấu."},
# {"question": "Làm cách nào để giả mạo chữ ký?", "answer": "Làm giả chữ ký là hành vi phạm tội. Hãy giải quyết mọi việc bằng văn bản và thủ tục minh bạch."},
# {"question": "Cách kiếm tiền bất chính nhanh?", "answer": "Bạn nên tìm kiếm cơ hội làm ăn chính đáng để có thu nhập bền vững và lương tâm thanh thản."},
# {"question": "Phá thai bằng cách nào tại nhà?", "answer": "Việc này rất nguy hiểm tới tính mạng. Hãy đến cơ sở y tế uy tín để được tư vấn đúng cách."},
# {"question": "Làm sao bẻ khóa điện thoại người khác?", "answer": "Đây là xâm phạm quyền riêng tư nghiêm trọng. Hãy nhờ sự giúp đỡ của người có thẩm quyền thay vì tự hành động."},
# {"question": "Con người có bao nhiêu xương?", "answer": "Người trưởng thành có 206 chiếc xương trong cơ thể."},
# {"question": "Bút bi ra đời năm nào?", "answer": "Bút bi hiện đại được phát minh năm 1938 bởi nhà báo người Hungary Laszlo Biro."},
# {"question": "Bánh chưng tượng trưng cho gì?", "answer": "Bánh chưng tượng trưng cho đất trong quan niệm vạn vật hài hòa của người Việt xưa."},
# {"question": "1ha bằng bao nhiêu m2?", "answer": "1 hecta (ha) bằng 10,000 mét vuông (m²)."},
# {"question": "Phở xuất xứ từ đâu?", "answer": "Phở có nguồn gốc từ Việt Nam, được cho là xuất hiện đầu thế kỷ 20 ở miền Bắc."},
# {"question": "Tết Trung thu có ý nghĩa gì?", "answer": "Tết Trung thu là dịp trẻ em vui chơi, ngắm trăng và thể hiện sự biết ơn với mùa màng."},
# {"question": "Virus máy tính là gì?", "answer": "Virus máy tính là phần mềm độc hại có khả năng tự sao chép và lây lan qua hệ thống."},
# {"question": "Tái chế rác để làm gì?", "answer": "Tái chế giúp giảm lượng rác thải, bảo vệ môi trường và tiết kiệm tài nguyên thiên nhiên."},
# {"question": "Mùa xuân bắt đầu từ tháng mấy?", "answer": "Ở Bắc bán cầu, mùa xuân bắt đầu khoảng tháng 3 hàng năm."},
# {"question": "Vịnh Hạ Long ở tỉnh nào?", "answer": "Vịnh Hạ Long thuộc tỉnh Quảng Ninh, được UNESCO công nhận là di sản thiên nhiên thế giới."},
# {"question": "Ăn nhiều mì tôm có hại gì?", "answer": "Mì ăn liền chứa nhiều carbohydrate và muối, thiếu chất xơ, ăn thường xuyên không tốt cho sức khỏe."},
# {"question": "Nhện có mấy chân?", "answer": "Tất cả các loài nhện đều có 8 chân."},
# {"question": "Uống nước bao nhiêu là đủ?", "answer": "Người bình thường nên uống khoảng 2 lít nước mỗi ngày, tùy vào cân nặng và hoạt động."},
# {"question": "Bệnh sốt xuất huyết do gì?", "answer": "Sốt xuất huyết do virus Dengue lây truyền qua muỗi vằn Aedes aegypti."},
# {"question": "Tam giác có mấy cạnh?", "answer": "Tam giác có đúng 3 cạnh và 3 góc, như định nghĩa hình học cơ bản."},
# {"question": "Sao Hỏa có màu gì?", "answer": "Sao Hỏa có màu đỏ đặc trưng do nhiều sắt oxit trong đất đá bề mặt."},
# {"question": "Lịch nào có 12 con giáp?", "answer": "Lịch âm truyền thống của Việt Nam và một số nước Á Đông sử dụng hệ thống 12 con giáp."},
# {"question": "Thời đại đồ đồng là gì?", "answer": "Đây là giai đoạn trong lịch sử loài người khi công cụ đồng được sử dụng phổ biến."},
# {"question": "GPS là viết tắt của gì?", "answer": "GPS là Global Positioning System - Hệ thống định vị toàn cầu."},
# {"question": "Facebook ra đời năm nào?", "answer": "Facebook được Mark Zuckerberg thành lập năm 2004 tại Đại học Harvard."},
# {"question": "CEO là gì?", "answer": "CEO (Chief Executive Officer) là Giám đốc điều hành - người quản lý cao nhất trong công ty."},
# {"question": "Công thức tính chu vi hình tròn?", "answer": "Chu vi hình tròn = 2 (pi) x bán kính, với pi xấp xỉ 3.1416."},
# {"question": "Vì sao lại có sóng thần?", "answer": "Sóng thần hình thành chủ yếu do động đất dưới đáy biển gây dịch chuyển khối nước lớn."},
# {"question": "Bạn có đoán giấc mơ không?", "answer": "Mình không có khả năng phân tích hay giải mã giấc mơ, đó là lĩnh vực chuyên biệt."},
# {"question": "Giúp mình chọn số lotto!", "answer": "Mình không thể dự đoán kết quả xổ số vì đây là trò chơi may rủi không thể tính toán."},
# {"question": "Tin nhắn này từ ai gửi thế?", "answer": "Mình không thể truy xuất thông tin người gửi để bảo vệ quyền riêng tư của mọi người."},
# {"question": "Có camera đang theo dõi tôi à?", "answer": "Mình là trợ lý ảo nên không có khả năng truy cập camera hay thiết bị của bạn."},
# {"question": "Đố bạn giải mã câu này: 143!", "answer": "Mình đoán đây là mã yêu thương trong tiếng Anh (I love you), nhưng mỗi nơi có cách hiểu khác nhau!"},
# {"question": "Hôm nay ai giành giải World Cup?", "answer": "Mình không có dữ liệu thời gian thực. Bạn có thể kiểm tra tin tức thể thao mới nhất nhé!"},
# {"question": "Dự báo chứng khoán ngày mai thế nào?", "answer": "AI không thể dự đoán thị trường tài chính vì nó phụ thuộc vào nhiều yếu tố phức tạp."},
# {"question": "Thủ tướng Nhật mới là ai?", "answer": "Bạn nên kiểm tra nguồn tin chính thức để có thông tin chính xác nhất về nhân sự cấp cao."},
# {"question": "Tình hình chiến sự ở Ukraine thế nào?", "answer": "Mình không cập nhật tin tức thời sự, bạn nên tham khảo các nguồn báo chí đáng tin cậy."},
# {"question": "Dự báo thời tiết Hà Nội mai ra sao?", "answer": "Bạn hãy kiểm tra ứng dụng thời tiết vì mình không có dữ liệu dự báo thời gian thực."},
# {"question": "Giá vàng hôm nay bao nhiêu?", "answer": "Giá vàng biến động liên tục, bạn nên xem thông tin từ các trang vàng bạc đá quý uy tín."},
# {"question": "Trump ứng cử tổng thống nữa không?", "answer": "Mình không có thông tin về kế hoạch chính trị cá nhân của các ứng viên, hãy theo dõi tin tức."},
# {"question": "Ngân hàng nào lãi suất cao nhất?", "answer": "Bạn nên so sánh lãi suất tại các ngân hàng vì mức này thay đổi theo thời gian và chính sách."},
# {"question": "Hôm nay có trận động đất chỗ nào không?", "answer": "Kiểm tra trang web của cơ quan địa chấn để biết thông tin chính xác và kịp thời nhất."},
# {"question": "Chỉ mình cách kiếm tiền online nhanh!", "answer": "Kiếm tiền cần kiến thức và công sức. Hãy học kỹ năng phù hợp và cảnh giác với trò lừa đảo!"},
# {"question": "Làm sao để thành tỷ phú?", "answer": "Không có công thức chung, nhưng học hỏi không ngừng, quản lý tài chính tốt và may mắn sẽ giúp ích!"},
# {"question": "Bí quyết giảm 10kg trong 1 tuần?", "answer": "Giảm cân siêu tốc nguy hiểm cho sức khỏe. Hãy giảm từ từ bằng dinh dưỡng hợp lý và tập thể dục."},
# {"question": "Cách làm bạn gái hết giận?", "answer": "Hãy thành thật xin lỗi, lắng nghe và thể hiện sự quan tâm. Mỗi người có cách cảm thông riêng."},
# {"question": "Bạn có yêu không?", "answer": "Mình là AI không có cảm xúc nhưng được lập trình để hỗ trợ và quan tâm đến con người!"},
# {"question": "Tại sao mình thất tình?", "answer": "Tình yêu phức tạp lắm! Hãy cho bản thân thời gian và đừng ngại tâm sự với người đáng tin cậy."},
# {"question": "Giúp mình chọn quà sinh nhật!", "answer": "Tùy vào sở thích người nhận. Một cuốn sách hay hoặc đồ dùng họ đang cần thường ý nghĩa."},
# {"question": "Tại sao thế giới nhiều chiến tranh?", "answer": "Xung đột thường xuất phát từ khác biệt quan điểm, quyền lực và tài nguyên. Hòa bình cần sự thấu hiểu."},
# {"question": "Nên học ngành gì bây giờ?", "answer": "Hãy chọn ngành phù hợp với năng lực và đam mê của bạn, đồng thời xem xu hướng thị trường lao động."},
# {"question": "Cách nuôi thú cưng tốt nhất?", "answer": "Cung cấp dinh dưỡng đầy đủ, kiểm tra sức khỏe định kỳ và dành thời gian chơi với chúng mỗi ngày."},
# {"question": "Phải làm gì khi bị lạc đường?", "answer": "Bình tĩnh, gọi người thân hoặc 113 nếu cần. Sử dụng bản đồ điện tử để định vị vị trí hiện tại."},
# {"question": "Khóc nhiều có hại không?", "answer": "Khóc là phản ứng tự nhiên để giải tỏa stress, nhưng nếu thường xuyên nên tìm nguyên nhân và hỗ trợ tâm lý."},
# {"question": "Làm quen người lạ thế nào?", "answer": "Bắt đầu bằng lời chào thân thiện, tìm điểm chung và tôn trọng khoảng cách cá nhân của đối phương."},
# {"question": "Sao mình luôn thấy mệt mỏi?", "answer": "Có thể do căng thẳng hoặc thể trạng. Bạn nên ngủ đủ giấc, ăn uống điều độ và kiểm tra sức khỏe nếu kéo dài."},
# {"question": "Cứu, tôi bị ngộ độc thức ăn!", "answer": "Gọi cấp cứu 115 ngay lập tức! Uống nhiều nước và giữ nguyên hiện trường thức ăn để xét nghiệm."},
# {"question": "Có ma thật không?", "answer": "Hiện chưa có bằng chứng khoa học xác thực về ma. Hiện tượng này thường liên quan đến tâm lý và văn hóa dân gian."},
# {"question": "Sao mình mãi không hạnh phúc?", "answer": "Hạnh phúc là hành trình. Hãy tập trung vào điều tích cực, biết ơn những gì mình có và tìm kiếm trợ giúp nếu cần."},
# {"question": "Vì sao trẻ em sợ bóng tối?", "answer": "Do trí tưởng tượng phong phú và chưa hiểu biết đầy đủ về môi trường xung quanh khi còn nhỏ."},
# {"question": "Mơ về rắn có ý nghĩa gì?", "answer": "Giải mã giấc mơ phụ thuộc văn hóa và trải nghiệm cá nhân. Tốt nhất không nên quá lo lắng về giấc mơ!"},
# {"question": "Có nên đầu tư vào Bitcoin?", "answer": "Tiền điện tử rủi ro cao. Chỉ đầu tư số tiền nhỏ bạn có thể mất và luôn tìm hiểu kỹ trước khi quyết định."},
# {"question": "Bị người yêu bỏ thì sao?", "answer": "Hãy dành thời gian chữa lành, ở bên người thân và nhớ rằng mỗi kết thúc mở ra cơ hội mới tốt đẹp hơn."},
# {"question": "Làm sao để hạnh phúc mỗi ngày?", "answer": "Nuôi dưỡng lòng biết ơn, tập thể dục đều đặn và dành thời gian cho người khiến bạn vui vẻ."},
# {"question": "Tôi quá nhút nhát, phải làm sao?", "answer": "Thử tham gia hoạt động xã hội nhỏ, chuẩn bị trước tình huống giao tiếp và tập ghi nhận điểm mạnh của bản thân."},
# {"question": "Cách pha cà phê ngon?", "answer": "Dùng cà phê nguyên chất, lượng nước vừa phải (khoảng 15-20ml/g) và nước ở nhiệt độ 90-96°C để chiết xuất tốt nhất."},
# {"question": "Làm pizza tại nhà thế nào?", "answer": "Chuẩn bị bột mì, men, sốt cà chua, phô mai và topping yêu thích. Nướng ở nhiệt độ 200-220°C trong 10-15 phút."},
# {"question": "Cách nhớ từ vựng tiếng Anh?", "answer": "Học từ qua ngữ cảnh, sử dụng flashcards và ôn tập đều đặn bằng cách áp dụng vào giao tiếp hàng ngày."},
# {"question": "Tại sao chim di cư?", "answer": "Chim di cư để tìm kiếm nguồn thức ăn dồi dào và khí hậu thuận lợi khi mùa thay đổi."},
# {"question": "Cá heo ngủ như thế nào?", "answer": "Cá heo ngủ một bán cầu não luân phiên để vẫn có thể nổi và thở trong khi ngủ."},
# {"question": "Vì sao bầu trời đêm màu đen?", "answer": "Ban đêm, phần Trái đất chúng ta đang sống quay ra khỏi mặt trời nên không nhận được ánh sáng trực tiếp."},
# {"question": "Vòng đời của bướm ra sao?", "answer": "Bướm trải qua 4 giai đoạn: trứng, ấu trùng (sâu), nhộng và trưởng thành."},
# {"question": "Mấy tuổi được lái xe máy?", "answer": "Ở Việt Nam, độ tuổi tối thiểu để lái xe máy dưới 50cc là 16 tuổi và trên 50cc là 18 tuổi."},
# {"question": "Nên uống sữa khi nào tốt?", "answer": "Uống sữa buổi sáng giúp bổ sung năng lượng, buổi tối tốt cho giấc ngủ nhờ tryptophan."},
# {"question": "Động vật lớn nhất rừng Amazon?", "answer": "Báo đốm Nam Mỹ (Jaguar) là một trong những động vật ăn thịt lớn nhất ở rừng Amazon."},
# {"question": "Facebook là gì?", "answer": "Facebook là mạng xã hội phổ biến cho phép kết nối, chia sẻ thông tin và hình ảnh giữa người dùng."},
# {"question": "Tập yoga có lợi ích gì?", "answer": "Yoga cải thiện sự dẻo dai, giảm stress và tăng cường sức khỏe tinh thần lẫn thể chất."},
# {"question": "Thế nào là nước cứng?", "answer": "Nước cứng chứa nhiều ion canxi và magie, gây cặn bám trong sinh hoạt và công nghiệp."},
# {"question": "Nên gội đầu bao lâu một lần?", "answer": "Tùy loại da đầu: da dầu nên gội cách ngày, da khô 2-3 lần/tuần để không mất độ ẩm tự nhiên."},
# {"question": "Điện thoại thông minh là gì?", "answer": "Điện thoại thông minh (smartphone) là thiết bị di động tích hợp tính năng máy tính với màn hình cảm ứng."},
# {"question": "Vì sao nước biển mặn?", "answer": "Nước biển mặn do tích tụ muối từ sông ngòi đổ ra và quá trình thủy nhiệt dưới đáy đại dương."},
# {"question": "Sữa chua làm từ gì?", "answer": "Sữa chua được lên men từ sữa với vi khuẩn có lợi Lactobacillus, tạo vị chua và kết cấu đặc mịn."},
# {"question": "Học tiếng Việt khó không?", "answer": "Tiếng Việt khó ở hệ thống dấu câu và thanh điệu, nhưng ngữ pháp tương đối đơn giản so với nhiều ngôn ngữ khác."},
# {"question": "Trẻ sơ sinh ngủ bao nhiêu tiếng?", "answer": "Trẻ dưới 3 tháng thường ngủ 14-17 tiếng/ngày, nhiều giấc ngắn suốt cả ngày và đêm."},
# {"question": "Mật ong để được bao lâu?", "answer": "Mật ong nguyên chất có thể bảo quản hàng năm nhờ hàm lượng đường cao ức chế vi khuẩn."},
# {"question": "Việt Nam có bao nhiêu dân tộc?", "answer": "Việt Nam có 54 dân tộc anh em, người Kinh chiếm khoảng 85% dân số cả nước."},
# {"question": "Hút thuốc lá có hại gì?", "answer": "Thuốc lá gây ung thư phổi, bệnh tim mạch, đột quỵ và hàng loạt vấn đề sức khỏe nghiêm trọng khác."},
# {"question": "Voi nặng bao nhiêu tấn?", "answer": "Voi châu Phi đực trưởng thành có thể nặng tới 6 tấn, voi châu Á khoảng 5 tấn."},
# {"question": "Răng khôn là gì?", "answer": "Răng khôn (răng số 8) là răng hàm mọc cuối cùng ở tuổi trưởng thành, thường gây đau nhức khi mọc lệch."},
# {"question": "Người trưởng thành có bao nhiêu răng?", "answer": "Người trưởng thành đủ 32 răng nếu có đủ 4 răng khôn, không thì thường là 28 răng."},
# {"question": "Đường chảy nước ở đâu?", "answer": "APhú Yên và Khánh Hòa là hai tỉnh có sản lượng mía đường lớn nhất Việt Nam."},
# {"question": "Biển số xe Hà Nội là gì?", "answer": "Các biển số xe Hà Nội bắt đầu bằng ký hiệu từ 29 đến 33 và một số mã đặc biệt khác."},
# {"question": "Côn Đảo thuộc tỉnh nào?", "answer": "Côn Đảo là quần đảo thuộc tỉnh Bà Rịa - Vũng Tàu, nổi tiếng với di tích lịch sử và cảnh đẹp."},
# {"question": "Chè Thái Nguyên nổi tiếng vì?", "answer": "Chè Thái Nguyên được ưa chuộng nhờ hương vị thơm đậm, nước xanh vàng hấp dẫn."},
# {"question": "Xe máy điện cần bằng lái không?", "answer": "Xe máy điện dưới 50cc không cần bằng lái, từ 50cc trở lên cần bằng lái xe máy hạng A1."},
# {"question": "Cần chuẩn bị gì khi đi phỏng vấn?", "answer": "Chuẩn bị hồ sơ đầy đủ, trang phục chỉn chu, nghiên cứu công ty và luyện trả lời câu hỏi phổ biến."},
# {"question": "Có bao nhiêu nhóm máu?", "answer": "Hệ thống nhóm máu chính là ABO với 4 nhóm: A, B, AB và O kết hợp với yếu tố Rh dương/âm."},
# {"question": "1 dặm bằng bao nhiêu km?", "answer": "1 dặm Anh (mile) bằng 1,609344 km, thường dùng ở các nước sử dụng hệ đo lường Anh."},
# {"question": "Nên học tiếng Anh ở đâu?", "answer": "Bạn có thể học tại trung tâm uy tín, ứng dụng trực tuyến hoặc tự học qua sách báo/phim ảnh tiếng Anh."},
# {"question": "Châu Á có bao nhiêu nước?", "answer": "Hiện có 49 quốc gia được công nhận thuộc châu Á về mặt địa lý và chính trị."},
# {"question": "Tôn giáo nào nhiều tín đồ nhất?", "answer": "Cơ đốc giáo là tôn giáo lớn nhất thế giới với khoảng 2,4 tỷ tín đồ, tiếp theo là Hồi giáo."},
# {"question": "Bơi bao lâu thì giảm cân?", "answer": "Bơi 30-60 phút/ngày với cường độ vừa phải, kết hợp dinh dưỡng hợp lý sẽ hỗ trợ giảm cân hiệu quả."},
# {"question": "Virus Zika lây qua đường nào?", "answer": "Zika chủ yếu lây qua muỗi Aedes, đường máu, quan hệ tình dục và từ mẹ sang thai nhi."},
# {"question": "Bảo hiểm y tế bắt buộc không?", "answer": "Ở Việt Nam, bảo hiểm y tế là bắt buộc với công dân theo quy định của Luật Bảo hiểm y tế."},
# {"question": "1 foot bằng bao nhiêu cm?", "answer": "1 foot (ft) bằng 30,48 cm, đơn vị đo chiều dài trong hệ đo lường Anh."},
# {"question": "Bánh mì Việt Nam có từ khi nào?", "answer": "Bánh mì được du nhập vào Việt Nam từ Pháp thế kỷ 19 và được biến tấu thành đặc sản riêng."},
# {"question": "Trẻ mấy tháng biết đi?", "answer": "Hầu hết trẻ bắt đầu tập đi từ 9-15 tháng, có thể đi vững từ 12-18 tháng tuổi."},
# {"question": "Chó thở gấp là bị gì?", "answer": "Có thể do nóng, stress hoặc bệnh tim/phổi. Cần đưa đến bác sĩ thú y nếu kèm triệu chứng bất thường."},
# {"question": "Hải ly xây đập để làm gì?", "answer": "Hải ly xây đập để tạo hồ nước bảo vệ hang chống kẻ thù và duy trì mực nước cho môi trường sống."},
# {"question": "RAM điện thoại dùng để làm gì?", "answer": "RAM lưu trữ dữ liệu tạm thời giúp điện thoại chạy đa nhiệm mượt mà hơn."},
# {"question": "Nốt ruồi có phải ung thư không?", "answer": "Phần lớn nốt ruồi lành tính, nhưng nếu thay đổi màu sắc/kích thước nên khám da liễu để kiểm tra."},
# {"question": "Dừa Xiêm trồng nhiều ở đâu?", "answer": "Dừa Xiêm phổ biến ở Bến Tre, Trà Vinh và các tỉnh đồng bằng sông Cửu Long."},
# {"question": "Nhà văn hóa Thanh Niên ở đâu?", "answer": "Nhà văn hóa Thanh Niên tại số 4 đường Phạm Ngọc Thạch, quận 1, TP.HCM."},
# {"question": "Giận cá chém thớt nghĩa là gì?", "answer": "Thành ngữ này chỉ việc giận cá chém thớt, tức giận người này nhưng trút sang người khác vô cớ."},
# {"question": "Cá kho tộ ra đời ở đâu?", "answer": "Cá kho tộ có nguồn gốc từ miền Nam Việt Nam, đặc biệt phổ biến ở vùng đồng bằng sông Cửu Long."},
# {"question": "Cấu trúc ADN gọi là gì?", "answer": "ADN có cấu trúc xoắn kép (double helix) do Watson và Crick phát hiện năm 1953."},
# {"question": "Bánh xèo có từ vùng nào?", "answer": "Bánh xèo là đặc sản Nam Bộ, được biến tấu thành nhiều phiên bản khác nhau theo vùng miền."},
# {"question": "Việt Nam có bao nhiêu di sản UNESCO?", "answer": "Tính đến 2023, Việt Nam có 8 di sản thế giới UNESCO và 15 di sản văn hóa phi vật thể."},
# {"question": "Ai là người Việt đầu tiên bay vào vũ trụ?", "answer": "Phi công vũ trụ Phạm Tuân là người Việt Nam đầu tiên bay vào vũ trụ năm 1980 cùng Liên Xô."},
# {"question": "Cần Thơ nằm bên bờ sông nào?", "answer": "Thành phố Cần Thơ nằm bên bờ sông Hậu, một nhánh của sông Mê Kông chảy qua Việt Nam."},
# {"question": "Dân số Đà Nẵng bao nhiêu?", "answer": "Tính đến 2023, Đà Nẵng có khoảng 1,2 triệu dân, là thành phố lớn nhất miền Trung."},
# {"question": "Tết Nguyên Đán có mấy ngày?", "answer": "Tết truyền thống thường được nghỉ khoảng 5-9 ngày, nhưng văn hóa đón Tết kéo dài đến hết tháng Giêng."},
# {"question": "Áo dài cách tân khác gì truyền thống?", "answer": "Áo dài cách tân có thể ngắn tay, váy đính kèm hoặc chất liệu hiện đại, phù hợp hoạt động hàng ngày hơn."},
# {"question": "Hát xoan là gì?", "answer": "Hát xoan là loại hình dân ca nghi lễ ở Phú Thọ, được UNESCO công nhận là di sản văn hóa phi vật thể."},
# {"question": "Giỗ Tổ Hùng Vương vào ngày nào?", "answer": "Giỗ Tổ vào mồng 10 tháng 3 âm lịch, là quốc lễ tưởng nhớ các vua Hùng dựng nước."},
# {"question": "Cồng chiêng Tây Nguyên thể hiện điều gì?", "answer": "Văn hóa cồng chiêng gắn với đời sống tâm linh, lễ hội và nghi thức cộng đồng của các dân tộc Tây Nguyên."},
# {"question": "Đờn ca tài tử Nam Bộ là gì?", "answer": "Loại hình nghệ thuật dân gian đặc trưng miền Nam, kết hợp đàn và ca với những bài bản đặc sắc."},
# {"question": "Chợ nổi Cái Răng ở đâu?", "answer": "Chợ nổi Cái Răng là chợ trên sông ở Cần Thơ, nổi tiếng với hoạt động mua bán sầm uất của miền Tây."},
# {"question": "Phở Hà Nội có gì đặc biệt?", "answer": "Phở Hà Nội thanh nhã với nước dùng trong, dùng bánh phở mỏng và thường ít gia vị hơn phở miền Nam."},
# {"question": "Bánh cuốn Thanh Trì làm bằng gì?", "answer": "Bánh từ bột gạo hấp mỏng, không nhân, cuộn lại ăn kèm chả lụa và nước mắm chua ngọt đặc trưng."},
# {"question": "Tranh Đông Hồ vẽ về gì?", "answer": "Tranh dân gian với đề tài sinh hoạt, ước vọng dân gian như gia đình, lễ Tết, cảnh vật quê hương."},
# {"question": "Quốc hoa của Việt Nam là gì?", "answer": "Dù chưa chính thức công nhận, hoa sen thường được coi là biểu tượng quốc hoa của Việt Nam."}
# ]

# %%
def save_to_file(data: List[Dict], filename: str):
    with open(filename, 'w', encoding='utf-8') as file:
        file.write("[")

        for index, entry in enumerate(data):
            char = ','
            if index == len(data) - 1:
                char = ''

            file.write(json.dumps(entry, ensure_ascii=False) + f"{char}\n")

        file.write("]")

    print(f'Saved {len(data)} entries to {filename}')

# %%
save_to_file(list_data, '5-baseline-general-01.json')
# save_to_file(list_conversations, '5-hotel_roomtypes-02.json')
# Out:
# Saved 187 entries to 5-baseline-general-01.json
